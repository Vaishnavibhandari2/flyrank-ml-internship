# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane

I selected **Lane 2: Refresh / Content Opportunity Scoring**.

I chose this lane because it helps identify which content pages should be reviewed first for refresh or improvement. Instead of manually reviewing every page, a data-driven ranking helps prioritize pages with the highest opportunity for improvement.
"""))
# Out:
# ## My Lane
#
# I selected **Lane 2: Refresh / Content Opportunity Scoring**.
#
# I chose this lane because it helps identify which content pages should be reviewed first for refresh or improvement. Instead of manually reviewing every page, a data-driven ranking helps prioritize pages with the highest opportunity for improvement.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Research Question

**Decision**
Which content pages should be prioritized for review and refresh?

**Action**
Review the highest-ranked pages and improve their content, freshness, or SEO.

**Cost of a Wrong Recommendation**
Reviewing the wrong pages wastes time and resources while high-impact pages may be ignored.

**Why Data / ML?**
Machine learning combines multiple signals such as impressions, clicks, CTR, engagement, and content age to rank pages more effectively than manual review.
"""))
# Out:
# ## Research Question
#
# **Decision**
# Which content pages should be prioritized for review and refresh?
#
# **Action**
# Review the highest-ranked pages and improve their content, freshness, or SEO.
#
# **Cost of a Wrong Recommendation**
# Reviewing the wrong pages wastes time and resources while high-impact pages may be ignored.
#
# **Why Data / ML?**
# Machine learning combines multiple signals such as impressions, clicks, CTR, engagement, and content age to rank pages more effectively than manual review.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
# Out:
# fatal: destination path 'flyrank-ml-internship-starter' already exists and is not an empty directory.

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ./flyrank-ml-internship-starter/outputs/refresh_queue_sample.csv
# ./flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv

# %%
import pandas as pd

df = pd.read_csv("flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv")

print("Total rows:", len(df))
print("\nTrend direction:")
print(df["trend_direction"].value_counts())
print("\nAverage CTR:", round(df["ctr"].mean(), 3))
# Out:
# Total rows: 30000
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Careful Words

This analysis is based on patterns observed in the available dataset. It supports decision-making but does not prove cause-and-effect relationships. Any recommendations should be reviewed by a human before action is taken.
"""))
# Out:
# ## Careful Words
#
# This analysis is based on patterns observed in the available dataset. It supports decision-making but does not prove cause-and-effect relationships. Any recommendations should be reviewed by a human before action is taken.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
